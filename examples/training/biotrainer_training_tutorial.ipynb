# %% [markdown]
# # Biotrainer Introduction Notebook: Compare results

# %% [markdown]
# In the following tutorial, we will use [biotrainer](https://github.com/sacdallago/biotrainer) to train a baseline model (negative control) for an existing predictor. We will use one_hot_encodings for that. Can we claim that our predictor performs better than the baseline?

# %% [markdown]
# ## 0. Install Biotrainer

# %%
# Create a virtual environment before, then run:
# !pip install biotrainer

# %% [markdown]
# ## 1. The prediction task and predictor
#
# In our example, we already trained a regression model on the [FLIP meltome dataset split mixed](https://github.com/J-SNACKKB/FLIP/tree/main/splits/meltome) with [ProtT5](https://github.com/agemagician/ProtTrans) embeddings. So, we created a model that predicts the meltdown temperature for a given protein sequence.
#
# A common metric to compare performance of regression models is the `root_mean_squared_error` (rmse). The "CI" variable means "confidence interval". Both the mean for the rmse and the ci come from bootstrapping the test set with the created model. This is to draw repeatedly from the test set with replacement (e.g. 30 times) and then calculate the performance on that set. You can learn more about bootstrapping here: https://math.mit.edu/~dav/05.dir/class24-prep-a.pdf
#
# Now, we already have the result on the test set for ProtT5 given:

# %%
from biotrainer_core.data_classes import Protocol

task_protocol = Protocol.sequence_to_value
prott5_rmse_mean = 9.564  # Not real data
prott5_rmse_ci = 0.63  # Not real data

# Bootstrapping config (sample_size == length of test set)
bootstrapping_confidence_level = 0.05
bootstrapping_iterations = 30

# %% [markdown]
# ## 2. Downloading the data
#
# For this regression task, we can download one simple FASTA file that contains both our sequences and the respective targets (meltdown temperature of the sequence).

# %%
import requests

url = "https://nextcloud.cit.tum.de/index.php/s/PY2bpHL8wJxJMHq/download"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

file_name = "biotrainer_meltome_mixed.fasta"
response = requests.get(url, headers=headers)
with open(file_name, "wb") as f:
    f.write(response.content)

# %% [markdown]
# ## 3. Defining the biotrainer configuration
#
# We already know our sequences and targets are stored in the downloaded fasta file. We also know the protocol and which embedder to use. The rest of the configurations are straight-forward.

# %%
biotrainer_config = {
    "protocol": task_protocol.name,  # We have a per-sequence regression task, so sequence_to_value
    "input_file": file_name,  # The path to the downloaded fasta file
    "model_choice": "FNN",  # Fully connected neural network
    "embedder_name": "one_hot_encoding",  # Name of the embedding model
    "num_epochs": 200,  # Define how long we want to train at max
}

# %% [markdown]
# ## 4. Running the experiment
#
# We are now ready to train our baseline prediction model!

# %%
from biotrainer.training import BiotrainerModel

results = BiotrainerModel().train(config=biotrainer_config)
# Out:
# ''
#                 <div id="biotrainer_status" style="margin: 10px 0;">
#                     Biotrainer Training Running...
#                 </div>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:05,811 INFO Logging training at: /home/sebie/PycharmProjects/biotrainerFork/examples/tutorials/output/dcdb9945f799683d";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:05,812 INFO ** Running biotrainer (v2.0.0+beta) training routine **";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:05,813 INFO Pipeline start time: 2026-07-09T13:48:05.686259";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:05,813 INFO Training FNN model with hash: dcdb9945f799683d";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:05,815 INFO Using seed: 42";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:05,816 INFO Using device: cuda";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:05,818 INFO [TRAINING PIPELINE] Setup complete!";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:05,819 INFO [TRAINING PIPELINE] Embedding...";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:05,819 INFO Using predefined embedder: one_hot_encoding";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:05,820 INFO Computing embeddings to: /home/sebie/PycharmProjects/biotrainerFork/examples/tutorials/output/embeddings/one_hot_encoding/reduced_embeddings_file_one_hot_encoding.h5";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:05,984 WARNING A sequence is 35213 residues long, which is longer than your `batch_size` parameter which is 6151";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:05,992 WARNING A sequence is 18562 residues long, which is longer than your `batch_size` parameter which is 6151";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:05,996 WARNING A sequence is 18141 residues long, which is longer than your `batch_size` parameter which is 6151";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:05,999 WARNING A sequence is 8797 residues long, which is longer than your `batch_size` parameter which is 6151";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:06,000 WARNING A sequence is 8545 residues long, which is longer than your `batch_size` parameter which is 6151";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:06,002 WARNING A sequence is 7570 residues long, which is longer than your `batch_size` parameter which is 6151";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:06,003 WARNING A sequence is 7406 residues long, which is longer than your `batch_size` parameter which is 6151";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:06,005 WARNING A sequence is 7355 residues long, which is longer than your `batch_size` parameter which is 6151";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:06,007 WARNING A sequence is 7354 residues long, which is longer than your `batch_size` parameter which is 6151";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:06,008 WARNING A sequence is 7158 residues long, which is longer than your `batch_size` parameter which is 6151";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:06,010 WARNING A sequence is 6994 residues long, which is longer than your `batch_size` parameter which is 6151";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:06,011 WARNING A sequence is 6885 residues long, which is longer than your `batch_size` parameter which is 6151";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:06,013 WARNING A sequence is 6669 residues long, which is longer than your `batch_size` parameter which is 6151";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:11,635 INFO Time elapsed for computing embeddings: 5.81[s]";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:11,864 INFO Loading embeddings from: /home/sebie/PycharmProjects/biotrainerFork/examples/tutorials/output/embeddings/one_hot_encoding/reduced_embeddings_file_one_hot_encoding.h5";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,487 INFO Read 20760 entries.";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,489 INFO Time elapsed for reading embeddings: 1.6[s]";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,490 INFO [TRAINING PIPELINE] Embedding done!";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,491 INFO [TRAINING PIPELINE] Loading data...";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,614 INFO [TRAINING PIPELINE] Data loaded!";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,614 INFO [TRAINING PIPELINE] Scaling features...";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,615 INFO No feature scaling performed (as configured).";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,615 INFO [TRAINING PIPELINE] Feature scaling complete!";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,616 INFO [TRAINING PIPELINE] Running projection...";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,616 INFO No dimension reduction performed (as configured).";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,617 INFO [TRAINING PIPELINE] Projection complete!";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,617 INFO [TRAINING PIPELINE] Creating datasets...";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,731 INFO Number of features (i.e. embedding dimension): 21";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,732 INFO Number of outputs (i.e. classes, equals 1 for regression): 1";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,733 INFO [TRAINING PIPELINE] Datasets created!";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,734 INFO [TRAINING PIPELINE] Training model...";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,735 INFO Training model for split hold_out:";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:13,748 INFO Checkpoint(s) will be stored at /home/sebie/PycharmProjects/biotrainerFork/examples/tutorials/output/dcdb9945f799683d/hold_out_checkpoint.safetensors";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,341 INFO Epoch 0";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,342 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,343 INFO 	loss: 2589.45";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,344 INFO 	mse: 2592.68";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,345 INFO 	rmse: 50.92";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,346 INFO 	spearmans-corr-coeff: 0.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,347 INFO 	ndcg: 0.47";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,347 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,348 INFO 	loss: 2657.40";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,349 INFO 	mse: 2658.97";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,349 INFO 	rmse: 51.57";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,350 INFO 	spearmans-corr-coeff: -0.05";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,351 INFO 	ndcg: 0.46";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,358 INFO Checkpoint(s) will be stored at /home/sebie/PycharmProjects/biotrainerFork/examples/tutorials/output/dcdb9945f799683d/hold_out_checkpoint.safetensors";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,814 INFO Epoch 1";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,815 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,816 INFO 	loss: 2443.04";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,817 INFO 	mse: 2437.95";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,818 INFO 	rmse: 49.38";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,818 INFO 	spearmans-corr-coeff: 0.02";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,819 INFO 	ndcg: 0.48";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,820 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,820 INFO 	loss: 2553.63";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,821 INFO 	mse: 2549.89";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,822 INFO 	rmse: 50.50";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,823 INFO 	spearmans-corr-coeff: -0.02";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:14,824 INFO 	ndcg: 0.49";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,257 INFO Epoch 2";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,257 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,258 INFO 	loss: 2157.98";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,259 INFO 	mse: 2160.11";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,260 INFO 	rmse: 46.48";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,260 INFO 	spearmans-corr-coeff: 0.00";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,261 INFO 	ndcg: 0.47";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,261 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,262 INFO 	loss: 2337.46";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,262 INFO 	mse: 2338.11";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,263 INFO 	rmse: 48.35";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,264 INFO 	spearmans-corr-coeff: -0.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,265 INFO 	ndcg: 0.48";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,707 INFO Epoch 3";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,709 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,710 INFO 	loss: 1758.38";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,711 INFO 	mse: 1755.45";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,712 INFO 	rmse: 41.90";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,712 INFO 	spearmans-corr-coeff: -0.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,713 INFO 	ndcg: 0.47";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,714 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,715 INFO 	loss: 1988.79";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,715 INFO 	mse: 1980.33";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,716 INFO 	rmse: 44.50";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,717 INFO 	spearmans-corr-coeff: 0.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:15,717 INFO 	ndcg: 0.51";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,195 INFO Epoch 4";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,197 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,199 INFO 	loss: 1307.96";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,200 INFO 	mse: 1310.12";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,201 INFO 	rmse: 36.20";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,202 INFO 	spearmans-corr-coeff: 0.00";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,203 INFO 	ndcg: 0.46";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,203 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,204 INFO 	loss: 1538.15";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,205 INFO 	mse: 1539.63";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,205 INFO 	rmse: 39.24";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,206 INFO 	spearmans-corr-coeff: 0.02";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,207 INFO 	ndcg: 0.48";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,662 INFO Epoch 5";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,664 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,666 INFO 	loss: 898.36";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,667 INFO 	mse: 901.04";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,667 INFO 	rmse: 30.02";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,668 INFO 	spearmans-corr-coeff: 0.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,669 INFO 	ndcg: 0.48";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,669 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,670 INFO 	loss: 1106.21";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,670 INFO 	mse: 1106.64";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,671 INFO 	rmse: 33.27";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,671 INFO 	spearmans-corr-coeff: 0.03";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:16,673 INFO 	ndcg: 0.49";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,115 INFO Epoch 6";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,116 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,117 INFO 	loss: 588.86";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,118 INFO 	mse: 586.04";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,118 INFO 	rmse: 24.21";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,119 INFO 	spearmans-corr-coeff: -0.00";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,119 INFO 	ndcg: 0.46";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,120 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,120 INFO 	loss: 734.93";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,120 INFO 	mse: 737.41";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,121 INFO 	rmse: 27.16";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,121 INFO 	spearmans-corr-coeff: 0.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,122 INFO 	ndcg: 0.50";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,533 INFO Epoch 7";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,534 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,535 INFO 	loss: 378.40";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,536 INFO 	mse: 376.50";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,537 INFO 	rmse: 19.40";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,538 INFO 	spearmans-corr-coeff: 0.02";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,539 INFO 	ndcg: 0.47";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,540 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,541 INFO 	loss: 462.51";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,542 INFO 	mse: 461.45";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,543 INFO 	rmse: 21.48";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,543 INFO 	spearmans-corr-coeff: -0.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,544 INFO 	ndcg: 0.49";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,977 INFO Epoch 8";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,978 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,979 INFO 	loss: 256.80";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,979 INFO 	mse: 257.78";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,980 INFO 	rmse: 16.06";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,980 INFO 	spearmans-corr-coeff: -0.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,981 INFO 	ndcg: 0.47";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,981 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,982 INFO 	loss: 310.19";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,982 INFO 	mse: 311.54";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,983 INFO 	rmse: 17.65";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,983 INFO 	spearmans-corr-coeff: 0.02";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:17,983 INFO 	ndcg: 0.49";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,515 INFO Epoch 9";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,516 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,517 INFO 	loss: 200.98";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,521 INFO 	mse: 201.70";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,522 INFO 	rmse: 14.20";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,523 INFO 	spearmans-corr-coeff: 0.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,524 INFO 	ndcg: 0.47";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,524 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,525 INFO 	loss: 216.37";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,526 INFO 	mse: 217.18";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,528 INFO 	rmse: 14.74";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,529 INFO 	spearmans-corr-coeff: 0.03";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,530 INFO 	ndcg: 0.52";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,959 INFO Epoch 10";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,960 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,961 INFO 	loss: 180.58";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,962 INFO 	mse: 181.07";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,963 INFO 	rmse: 13.46";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,963 INFO 	spearmans-corr-coeff: 0.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,964 INFO 	ndcg: 0.47";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,965 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,965 INFO 	loss: 181.76";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,966 INFO 	mse: 182.16";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,967 INFO 	rmse: 13.50";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,967 INFO 	spearmans-corr-coeff: 0.02";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:18,968 INFO 	ndcg: 0.52";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,444 INFO Epoch 11";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,445 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,446 INFO 	loss: 170.79";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,446 INFO 	mse: 171.94";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,447 INFO 	rmse: 13.11";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,447 INFO 	spearmans-corr-coeff: -0.00";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,448 INFO 	ndcg: 0.48";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,448 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,449 INFO 	loss: 163.65";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,449 INFO 	mse: 164.42";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,449 INFO 	rmse: 12.82";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,450 INFO 	spearmans-corr-coeff: 0.10";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,450 INFO 	ndcg: 0.49";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,862 INFO Epoch 12";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,863 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,864 INFO 	loss: 169.38";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,864 INFO 	mse: 169.86";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,865 INFO 	rmse: 13.03";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,865 INFO 	spearmans-corr-coeff: 0.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,866 INFO 	ndcg: 0.49";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,867 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,868 INFO 	loss: 175.83";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,869 INFO 	mse: 174.96";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,870 INFO 	rmse: 13.23";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,871 INFO 	spearmans-corr-coeff: -0.03";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:19,871 INFO 	ndcg: 0.50";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,290 INFO Epoch 13";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,291 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,291 INFO 	loss: 167.32";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,293 INFO 	mse: 168.27";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,294 INFO 	rmse: 12.97";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,294 INFO 	spearmans-corr-coeff: 0.02";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,295 INFO 	ndcg: 0.51";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,295 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,296 INFO 	loss: 173.07";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,296 INFO 	mse: 173.93";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,297 INFO 	rmse: 13.19";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,297 INFO 	spearmans-corr-coeff: -0.00";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,298 INFO 	ndcg: 0.50";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,728 INFO Epoch 14";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,729 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,730 INFO 	loss: 167.42";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,730 INFO 	mse: 167.13";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,731 INFO 	rmse: 12.93";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,731 INFO 	spearmans-corr-coeff: 0.03";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,732 INFO 	ndcg: 0.51";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,732 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,732 INFO 	loss: 166.11";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,733 INFO 	mse: 167.43";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,733 INFO 	rmse: 12.94";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,733 INFO 	spearmans-corr-coeff: 0.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:20,734 INFO 	ndcg: 0.50";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,136 INFO Epoch 15";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,137 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,138 INFO 	loss: 167.27";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,139 INFO 	mse: 168.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,139 INFO 	rmse: 12.96";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,140 INFO 	spearmans-corr-coeff: 0.02";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,140 INFO 	ndcg: 0.51";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,141 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,142 INFO 	loss: 159.29";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,142 INFO 	mse: 160.65";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,143 INFO 	rmse: 12.67";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,143 INFO 	spearmans-corr-coeff: 0.04";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,144 INFO 	ndcg: 0.56";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,568 INFO Epoch 16";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,572 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,573 INFO 	loss: 170.14";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,574 INFO 	mse: 170.06";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,576 INFO 	rmse: 13.04";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,579 INFO 	spearmans-corr-coeff: 0.02";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,580 INFO 	ndcg: 0.51";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,581 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,582 INFO 	loss: 173.82";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,583 INFO 	mse: 174.24";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,584 INFO 	rmse: 13.20";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,585 INFO 	spearmans-corr-coeff: 0.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,586 INFO 	ndcg: 0.49";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,979 INFO Epoch 17";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,980 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,981 INFO 	loss: 169.31";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,982 INFO 	mse: 168.36";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,983 INFO 	rmse: 12.98";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,984 INFO 	spearmans-corr-coeff: 0.02";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,985 INFO 	ndcg: 0.52";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,986 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,986 INFO 	loss: 173.60";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,987 INFO 	mse: 173.50";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,988 INFO 	rmse: 13.17";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:21,988 INFO 	spearmans-corr-coeff: 0.04";
#             </script>
#             <script>
# ...
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,552 INFO 	loss: 165.78";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,552 INFO 	mse: 166.69";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,553 INFO 	rmse: 12.91";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,553 INFO 	spearmans-corr-coeff: 0.04";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,554 INFO 	ndcg: 0.53";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,554 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,555 INFO 	loss: 162.13";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,556 INFO 	mse: 158.71";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,556 INFO 	rmse: 12.60";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,557 INFO 	spearmans-corr-coeff: 0.07";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,557 INFO 	ndcg: 0.55";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,981 INFO Epoch 35";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,982 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,982 INFO 	loss: 165.75";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,983 INFO 	mse: 166.58";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,983 INFO 	rmse: 12.91";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,984 INFO 	spearmans-corr-coeff: 0.04";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,984 INFO 	ndcg: 0.52";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,985 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,985 INFO 	loss: 162.77";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,985 INFO 	mse: 163.83";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,986 INFO 	rmse: 12.80";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,986 INFO 	spearmans-corr-coeff: 0.03";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:29,987 INFO 	ndcg: 0.56";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,421 INFO Epoch 36";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,422 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,423 INFO 	loss: 165.90";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,424 INFO 	mse: 166.91";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,425 INFO 	rmse: 12.92";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,426 INFO 	spearmans-corr-coeff: 0.04";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,426 INFO 	ndcg: 0.51";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,427 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,427 INFO 	loss: 168.08";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,428 INFO 	mse: 168.83";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,428 INFO 	rmse: 12.99";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,429 INFO 	spearmans-corr-coeff: 0.01";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,429 INFO 	ndcg: 0.50";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,905 INFO Epoch 37";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,906 INFO Training results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,907 INFO 	loss: 167.64";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,908 INFO 	mse: 166.95";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,908 INFO 	rmse: 12.92";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,908 INFO 	spearmans-corr-coeff: 0.03";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,909 INFO 	ndcg: 0.52";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,909 INFO Validation results";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,910 INFO 	loss: 162.10";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,910 INFO 	mse: 160.38";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,911 INFO 	rmse: 12.66";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,911 INFO 	spearmans-corr-coeff: 0.05";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,912 INFO 	ndcg: 0.55";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,913 INFO Early stopping triggered - patience limit is reached! (Best epoch: 26)";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,916 INFO Total training time for split hold_out: 17.16894145400147 [s]";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,917 INFO Running sanity checks on hold_out results ..";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,918 WARNING Training loss (164.30341705322266) is higher than validation loss (155.83639090401786) for CV split hold_out!";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,918 INFO Sanity check on hold_out results finished!";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,919 INFO Total elapsed time for training: 17.183728813000926 [s]";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,920 INFO [TRAINING PIPELINE] Training complete!";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,921 INFO [TRAINING PIPELINE] Testing model...";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,921 INFO Running final evaluation on the best model";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,924 INFO Loaded model from epoch: 26";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,976 INFO Test set test metrics: {'loss': 143.24889556884764, 'mse': 143.7172393798828, 'rmse': 11.988212585449219, 'spearmans-corr-coeff': 0.25115329027175903, 'ndcg': 0.8126595616340637}";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:30,977 INFO Running bootstrapping evaluation on the best model for test set (test)";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:31,204 INFO Bootstrapping results for test set (test): [BootstrappedMetric(name='mse', mean=144.54583740234375, lower=133.0437469482422, upper=159.84375, iterations=30, sample_size=3134, confidence_level=0.05), BootstrappedMetric(name='rmse', mean=12.020051956176758, lower=11.532812118530273, upper=12.645703315734863, iterations=30, sample_size=3134, confidence_level=0.05), BootstrappedMetric(name='spearmans-corr-coeff', mean=0.2508951723575592, lower=0.22236327826976776, upper=0.2754272520542145, iterations=30, sample_size=3134, confidence_level=0.05), BootstrappedMetric(name='ndcg', mean=0.811962902545929, lower=0.7838379144668579, upper=0.8389648199081421, iterations=30, sample_size=3134, confidence_level=0.05)]";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:31,206 INFO Running sanity checks on test set results (test) ..";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:31,489 INFO Random-Model Baseline: [BootstrappedMetric(name='mse', mean=2834.0, lower=2781.60009765625, upper=2889.35009765625, iterations=30, sample_size=3134, confidence_level=0.05), BootstrappedMetric(name='rmse', mean=53.23125076293945, lower=52.73828125, upper=53.75078201293945, iterations=30, sample_size=3134, confidence_level=0.05), BootstrappedMetric(name='spearmans-corr-coeff', mean=-0.14849039912223816, lower=-0.18130187690258026, upper=-0.11971740424633026, iterations=30, sample_size=3134, confidence_level=0.05), BootstrappedMetric(name='ndcg', mean=0.41704100370407104, lower=0.393890380859375, upper=0.445037841796875, iterations=30, sample_size=3134, confidence_level=0.05)]";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:31,685 INFO Random-Sampling Baseline: [BootstrappedMetric(name='mse', mean=685.683349609375, lower=665.0875244140625, upper=709.7374877929688, iterations=30, sample_size=3134, confidence_level=0.05), BootstrappedMetric(name='rmse', mean=26.184375762939453, lower=25.788280487060547, upper=26.646484375, iterations=30, sample_size=3134, confidence_level=0.05), BootstrappedMetric(name='spearmans-corr-coeff', mean=0.005123583599925041, lower=-0.020251845940947533, upper=0.03301355987787247, iterations=30, sample_size=3134, confidence_level=0.05), BootstrappedMetric(name='ndcg', mean=0.42029622197151184, lower=0.3997863829135895, upper=0.4377990961074829, iterations=30, sample_size=3134, confidence_level=0.05)]";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:31,851 INFO Mean-Only Baseline: [BootstrappedMetric(name='mse', mean=138.8937530517578, lower=128.1640625, upper=153.10311889648438, iterations=30, sample_size=3134, confidence_level=0.05), BootstrappedMetric(name='rmse', mean=11.782551765441895, lower=11.318359375, upper=12.377148628234863, iterations=30, sample_size=3134, confidence_level=0.05), BootstrappedMetric(name='spearmans-corr-coeff', mean=0.0, lower=0.0, upper=0.0, iterations=30, sample_size=3134, confidence_level=0.05), BootstrappedMetric(name='ndcg', mean=0.4192871153354645, lower=0.39549559354782104, upper=0.4411254823207855, iterations=30, sample_size=3134, confidence_level=0.05)]";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:31,852 INFO Sanity check on test results (test) finished!";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:31,854 INFO [TRAINING PIPELINE] Testing complete!";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:31,855 INFO [TRAINING PIPELINE] Running post-processing...";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:31,856 ERROR Could not save model as ONNX!";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:31,857 INFO Pipeline end time: 2026-07-09T13:48:31.857263";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:31,858 INFO Total elapsed time for pipeline: 26.171006502998353 [s]";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:31,859 INFO Extensive output information can be found at /home/sebie/PycharmProjects/biotrainerFork/examples/tutorials/output/out.yml";
#             </script>
#             <script>
#                 document.getElementById("biotrainer_status").innerHTML = "2026-07-09 13:48:31,859 INFO [TRAINING PIPELINE] Post-processing complete!";
#             </script>

# %% [markdown]
# ## 5. Comparing the results
#
# After our baseline model finished training, we can now compare it to the ProtT5 result.
#
# By the way, did you notice that the model did not train for the given 200 epochs? That is because there is a built-in mechanism called `early stopping` which should be used for any deep learning model. It avoids overfitting by stopping the training after a certain amount of epochs that did not increase the performance on the validation set. This "certain amount" can be defined in the training configuration by using `"patience": 50 (or some other positive integer value)`.

# %%
# First we get the bootstrapping results
bootstrapped_metrics = results.test_results["test"].bootstrapped_metrics
ohe_rmse_result = [res for res in bootstrapped_metrics if res.name == "rmse"][0]
ohe_rmse_mean = ohe_rmse_result.mean
ohe_rmse_ci = (ohe_rmse_result.upper - ohe_rmse_result.lower) / 2  # Assuming about symmetrical bounds

# Now let's compare them!
print(f"ProtT5: RMSE Mean: {prott5_rmse_mean} CI: {prott5_rmse_ci}")
print(f"OHE: RMSE Mean: {ohe_rmse_mean} CI: {ohe_rmse_ci}")
# Out:
# ProtT5: RMSE Mean: 9.564 CI: 0.63
# OHE: RMSE Mean: 12.020051956176758 CI: 0.5564455986022949

# %% [markdown]
# ## Final step: z-test
#
# Okay, only from looking at this, we can already calculate in our heads, that the confidence intervals do not overlap. That means that there is a significant difference between the two test set performances in our setup.
#
# But let's first verify that by using a statistical test, the so called "Z-Test".
# The Z-test essentially asks: 'Given these RMSE scores and their uncertainties from bootstrapping, what's the probability that the difference between ProtT5 and the simpler approach occurred by chance?'
#
# It works by:
#
# * Measuring how far apart the two RMSE means are
# * Taking into account how uncertain each measurement is (using the confidence intervals from our bootstrapping)
# * Comparing this to what we'd expect if there was no real difference between the approaches
#
# For example, if ProtT5 gives an RMSE of 3.2±0.2 and the simpler approach gives 4.1±0.2, the Z-test helps us confirm that ProtT5's better performance is 'real' and not just random variation. The test gives us a p-value: if it's less than 0.05, we can say that one approach is significantly better than the other.

# %%
import numpy as np
from scipy import stats

def z_test(mean1, ci1, mean2, ci2):
    # Convert CI to standard error for 95% CI
    se1 = ci1 / 1.96
    se2 = ci2 / 1.96
    z_stat = (mean1 - mean2) / np.sqrt(se1**2 + se2**2)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))  # two-tailed
    return z_stat, p_value

z_stat, p_value = z_test(prott5_rmse_mean, prott5_rmse_ci, ohe_rmse_mean, ohe_rmse_ci)
significant = p_value < 0.05

print(z_stat, p_value)
print(f"As {p_value} {'<' if significant else '>='} 0.05, we can assume that there is {'a' if significant else 'no'} significant difference between the performance of ProtT5 and one hot encodings!")
# Out:
# -5.727008052783661 1.0221731905346587e-08
# As 1.0221731905346587e-08 < 0.05, we can assume that there is a significant difference between the performance of ProtT5 and one hot encodings!
